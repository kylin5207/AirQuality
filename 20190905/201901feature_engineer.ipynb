# %% [markdown]
# <font size=5>1. 读取数据</font>

# %%
import pandas as pd
import numpy as np

# %%
stationID = "1316A"
datadate = "201901"

# %%
filename = "data/"+stationID+"/"+datadate+".csv"
filename
# Out:
# 'data/1316A/201901.csv'

# %%
data = pd.read_csv(filename, header=0, encoding="utf-8")

# %% [markdown]
# <font size=5>2. 查看数据格式及是否有缺失值<font>

# %%
#查看前五行数据
data.head()
# Out:
#        date  hour stationID    AQI  PM2.5  PM2.5_24h   PM10  PM10_24h   SO2  \
# 0  20190101     0     1316A  152.0  116.0       85.0  184.0     135.0  21.0
# 1  20190101     1     1316A  133.0  101.0       87.0  178.0     139.0  21.0
# 2  20190101     2     1316A  134.0  102.0       88.0  162.0     142.0  23.0
# 3  20190101     3     1316A  140.0  107.0       90.0  172.0     145.0  21.0
# 4  20190101     4     1316A  143.0  109.0       92.0  171.0     148.0  19.0
#
#    SO2_24h   NO2  NO2_24h   O3  O3_24h  O3_8h  O3_8h_24h   CO  CO_24h
# 0     21.0  79.0     65.0  6.0    48.0   13.0       35.0  1.6     1.3
# 1     21.0  79.0     66.0  6.0    48.0    6.0        6.0  1.6     1.3
# 2     21.0  79.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 3     22.0  78.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 4     21.0  77.0     67.0  6.0    48.0    6.0        6.0  1.8     1.4

# %%
#查看数据格式
data.dtypes
# Out:
# date           int64
# hour           int64
# stationID     object
# AQI          float64
# PM2.5        float64
# PM2.5_24h    float64
# PM10         float64
# PM10_24h     float64
# SO2          float64
# SO2_24h      float64
# NO2          float64
# NO2_24h      float64
# O3           float64
# O3_24h       float64
# O3_8h        float64
# O3_8h_24h    float64
# CO           float64
# CO_24h       float64
# dtype: object

# %%
#查看数据形状
data.shape
# Out:
# (744, 18)

# %%
#查看是否有缺失值
data.count()
# Out:
# date         744
# hour         744
# stationID    744
# AQI          709
# PM2.5        706
# PM2.5_24h    740
# PM10         702
# PM10_24h     740
# SO2          738
# SO2_24h      743
# NO2          733
# NO2_24h      743
# O3           735
# O3_24h       743
# O3_8h        743
# O3_8h_24h    743
# CO           737
# CO_24h       743
# dtype: int64

# %% [markdown]
# 这里可以看到还是有缺失值存在的
# **<font color=red>在将数据应用于系统之前，一定要对缺省值进行处理</font>**

# %%
#找出含有缺失值的列
hasNAN = data.isnull().any()
hasNAN[hasNAN==True]
# Out:
# AQI          True
# PM2.5        True
# PM2.5_24h    True
# PM10         True
# PM10_24h     True
# SO2          True
# SO2_24h      True
# NO2          True
# NO2_24h      True
# O3           True
# O3_24h       True
# O3_8h        True
# O3_8h_24h    True
# CO           True
# CO_24h       True
# dtype: bool

# %% [markdown]
# <font size=5>3. 处理缺失值</font>

# %% [markdown]
# 我的想法是：先找出含NAN值的列，然后分别计算这些列的均值，然后进行填充

# %%
#nancolslist存放含NAN值的列名信息
nancolslist = list(hasNAN[hasNAN==True].index)
len(nancolslist)
# Out:
# 15

# %%
#计算每一项指标的均值
for indicator in nancolslist:
    print(data[indicator].mean())
# Out:
# 163.04090267983074
# 96   10.0       21.0  3.100000     2.1
# 97    7.0        7.0  3.000000     2.2
# 98    6.0        7.0  3.100000     2.3
# 99    6.0        7.0  3.100000     2.4

# %% [markdown]
# 这样就填充好缺失值了，可以进行下一步操作。

# %% [markdown]
# <font size=5>4. 日期处理</font>

# %% [markdown]
# 毕竟是时间序列，肯定要对时间进行处理。

# %%
#查看datetime类型
type(data.date)
# Out:
# pandas.core.series.Series

# %%
#将数据转化为datetime类型
data["date"]= pd.to_datetime(data["date"], format='%Y%m%d')

# %%
data.shape
# Out:
# (744, 18)

# %%
#查看更改为datetime类型的date数据
data.head()
# Out:
#         date  hour stationID    AQI  PM2.5  PM2.5_24h   PM10  PM10_24h   SO2  \
# 0 2019-01-01     0     1316A  152.0  116.0       85.0  184.0     135.0  21.0
# 1 2019-01-01     1     1316A  133.0  101.0       87.0  178.0     139.0  21.0
# 2 2019-01-01     2     1316A  134.0  102.0       88.0  162.0     142.0  23.0
# 3 2019-01-01     3     1316A  140.0  107.0       90.0  172.0     145.0  21.0
# 4 2019-01-01     4     1316A  143.0  109.0       92.0  171.0     148.0  19.0
#
#    SO2_24h   NO2  NO2_24h   O3  O3_24h  O3_8h  O3_8h_24h   CO  CO_24h
# 0     21.0  79.0     65.0  6.0    48.0   13.0       35.0  1.6     1.3
# 1     21.0  79.0     66.0  6.0    48.0    6.0        6.0  1.6     1.3
# 2     21.0  79.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 3     22.0  78.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 4     21.0  77.0     67.0  6.0    48.0    6.0        6.0  1.8     1.4

# %%
#查看下类型
data.dtypes
# Out:
# date         datetime64[ns]
# hour                  int64
# stationID            object
# AQI                 float64
# PM2.5               float64
# PM2.5_24h           float64
# PM10                float64
# PM10_24h            float64
# SO2                 float64
# SO2_24h             float64
# NO2                 float64
# NO2_24h             float64
# O3                  float64
# O3_24h              float64
# O3_8h               float64
# O3_8h_24h           float64
# CO                  float64
# CO_24h              float64
# dtype: object

# %% [markdown]
# 在这里发现date真的转换位datetime类型

# %% [markdown]
# 目前的datetime中年月日信息是连在一起的，便于后续操作，我们把信息独立分成三列

# %%
data["year"] = pd.DatetimeIndex(data.date).year
data["month"] = pd.DatetimeIndex(data.date).month
data["day"] = pd.DatetimeIndex(data.date).day

# %% [markdown]
# 考虑到周末和工作日人们的生活方式可能与平常不大相同，单独再增加一列dayOfWeek，表示当前是一周的第几天

# %%
data["dayOfWeek"] = pd.DatetimeIndex(data.date).dayofweek

# %% [markdown]
# **<font color=red size=3>注意：dayOfWeek开始值是0，而不是我们想象中的周一，结束值是6，代表周日</font>**

# %%
#再看下当前数据
data.head()
# Out:
#         date  hour stationID    AQI  PM2.5  PM2.5_24h   PM10  PM10_24h   SO2  \
# 0 2019-01-01     0     1316A  152.0  116.0       85.0  184.0     135.0  21.0
# 1 2019-01-01     1     1316A  133.0  101.0       87.0  178.0     139.0  21.0
# 2 2019-01-01     2     1316A  134.0  102.0       88.0  162.0     142.0  23.0
# 3 2019-01-01     3     1316A  140.0  107.0       90.0  172.0     145.0  21.0
# 4 2019-01-01     4     1316A  143.0  109.0       92.0  171.0     148.0  19.0
#
#    SO2_24h    ...       O3  O3_24h  O3_8h  O3_8h_24h   CO  CO_24h  year  \
# 0     21.0    ...      6.0    48.0   13.0       35.0  1.6     1.3  2019
# 1     21.0    ...      6.0    48.0    6.0        6.0  1.6     1.3  2019
# 2     21.0    ...      6.0    48.0    6.0        6.0  1.7     1.3  2019
# 3     22.0    ...      6.0    48.0    6.0        6.0  1.7     1.3  2019
# 4     21.0    ...      6.0    48.0    6.0        6.0  1.8     1.4  2019
#
#    month  day  dayOfWeek
# 0      1    1          1
# 1      1    1          1
# 2      1    1          1
# 3      1    1          1
# 4      1    1          1
#
# [5 rows x 22 columns]

# %%
#查看更新后的data的shape：
data.shape
# Out:
# (744, 22)

# %% [markdown]
# 这里可以看到，由之前的18列扩展为22列。因为我们新增了四列：year,month,day,dayOfWeek

# %% [markdown]
# 其实，此时的date、stationID数据就不是很有用了，我们可以先将这列去掉，<font color=red>不过保险起见，我们先保存一下吧</font>

# %%
initialData = data

# %%
#扔掉date、stationID字段
data = data.drop(["date", "stationID"], axis=1)

# %%
#查看data的shape:
data.shape
# Out:
# (744, 20)

# %% [markdown]
# 可以发现由于我们删掉了两列，此时的数据从22列变为20列

# %%
#重新查看数据
data.head()
# Out:
#    hour    AQI  PM2.5  PM2.5_24h   PM10  PM10_24h   SO2  SO2_24h   NO2  \
# 0     0  152.0  116.0       85.0  184.0     135.0  21.0     21.0  79.0
# 1     1  133.0  101.0       87.0  178.0     139.0  21.0     21.0  79.0
# 2     2  134.0  102.0       88.0  162.0     142.0  23.0     21.0  79.0
# 3     3  140.0  107.0       90.0  172.0     145.0  21.0     22.0  78.0
# 4     4  143.0  109.0       92.0  171.0     148.0  19.0     21.0  77.0
#
#    NO2_24h   O3  O3_24h  O3_8h  O3_8h_24h   CO  CO_24h  year  month  day  \
# 0     65.0  6.0    48.0   13.0       35.0  1.6     1.3  2019      1    1
# 1     66.0  6.0    48.0    6.0        6.0  1.6     1.3  2019      1    1
# 2     67.0  6.0    48.0    6.0        6.0  1.7     1.3  2019      1    1
# 3     67.0  6.0    48.0    6.0        6.0  1.7     1.3  2019      1    1
# 4     67.0  6.0    48.0    6.0        6.0  1.8     1.4  2019      1    1
#
#    dayOfWeek
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# 这样数据好很多了，就是位置需要再调整一下

# %%
orderlist = ["year", "month", "day", "hour", "AQI", "PM2.5", "PM2.5_24h", "PM10", "PM10_24h","SO2","SO2_24h","NO2","NO2_24h","O3", "O3_24h", "O3_8h", "O3_8h_24h", "CO", "CO_24h", "dayOfWeek"]
data = data[orderlist]
data.head()
# Out:
#    year  month  day  hour    AQI  PM2.5  PM2.5_24h   PM10  PM10_24h   SO2  \
# 0  2019      1    1     0  152.0  116.0       85.0  184.0     135.0  21.0
# 1  2019      1    1     1  133.0  101.0       87.0  178.0     139.0  21.0
# 2  2019      1    1     2  134.0  102.0       88.0  162.0     142.0  23.0
# 3  2019      1    1     3  140.0  107.0       90.0  172.0     145.0  21.0
# 4  2019      1    1     4  143.0  109.0       92.0  171.0     148.0  19.0
#
#    SO2_24h   NO2  NO2_24h   O3  O3_24h  O3_8h  O3_8h_24h   CO  CO_24h  \
# 0     21.0  79.0     65.0  6.0    48.0   13.0       35.0  1.6     1.3
# 1     21.0  79.0     66.0  6.0    48.0    6.0        6.0  1.6     1.3
# 2     21.0  79.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 3     22.0  78.0     67.0  6.0    48.0    6.0        6.0  1.7     1.3
# 4     21.0  77.0     67.0  6.0    48.0    6.0        6.0  1.8     1.4
#
#    dayOfWeek
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1

# %% [markdown]
# 可以看到，数据整洁了很多

# %%
#再查看下数据类型
data.dtypes
# Out:
# year           int64
# month          int64
# day            int64
# hour           int64
# AQI          float64
# PM2.5        float64
# PM2.5_24h    float64
# PM10         float64
# PM10_24h     float64
# SO2          float64
# SO2_24h      float64
# NO2          float64
# NO2_24h      float64
# O3           float64
# O3_24h       float64
# O3_8h        float64
# O3_8h_24h    float64
# CO           float64
# CO_24h       float64
# dayOfWeek      int64
# dtype: object

# %% [markdown]
# <font size=5>5. 将DataFrame格式的数据转化为ndarray类型</font>

# %% [markdown]
# <font color=red>选择目标值为AQI指数，空气质量指数（也就是手机里面经常看到的）</font>

# %%
data_target = data["AQI"].values

# %%
data_target.shape
# Out:
# (744,)

# %% [markdown]
# <font color=red>剩下的数据作为特征数据</font>

# %%
data_features = data.drop(["AQI"], axis=1).values
data_features
# Out:
# array([[2.019e+03, 1.000e+00, 1.000e+00, ..., 1.600e+00, 1.300e+00,
#         1.000e+00],
#        [2.019e+03, 1.000e+00, 1.000e+00, ..., 1.600e+00, 1.300e+00,
#         1.000e+00],
#        [2.019e+03, 1.000e+00, 1.000e+00, ..., 1.700e+00, 1.300e+00,
#         1.000e+00],
#        ...,
#        [2.019e+03, 1.000e+00, 3.100e+01, ..., 1.100e+00, 1.100e+00,
#         3.000e+00],
#        [2.019e+03, 1.000e+00, 3.100e+01, ..., 1.000e+00, 1.100e+00,
#         3.000e+00],
#        [2.019e+03, 1.000e+00, 3.100e+01, ..., 1.000e+00, 1.100e+00,
#         3.000e+00]])

# %%
data_features.shape
# Out:
# (744, 19)

# %% [markdown]
# **<font size=6>机器学习算法</font>**

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import KFold
from sklearn import svm
from sklearn.model_selection import cross_val_score

# %% [markdown]
# 使用K折交叉验证方式

# %%
kfold = KFold(n_splits=3, shuffle=True, random_state=0)

# %%
#三折交叉验证
kfold.get_n_splits(data_features)
# Out:
# 3

# %% [markdown]
# 我们利用SVM中的SVR支持向量回归查看下数据的运行效果

# %%
for train_index,test_index in kfold.split(data_features):
    data_train, data_test = data_features[train_index], data_features[test_index]
    target_train, target_test = data_target[train_index], data_target[test_index]
    svc = svm.SVR(kernel='rbf', C=10, gamma=0.001)
    svc.fit(data_train, target_train)
    print("在训练集上的精度:{:.2f}".format(svc.score(data_train,target_train)))
    print("在测试集上的精度:{:.2f}".format(svc.score(data_test,target_test)))
# Out:
# 在训练集上的精度:0.56
# 在测试集上的精度:0.51
# 在训练集上的精度:0.62
# 在测试集上的精度:0.47
# 在训练集上的精度:0.57
# 在测试集上的精度:0.44
